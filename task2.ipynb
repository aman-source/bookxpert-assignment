# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Category</th>
#       <th>Model</th>
#       <th>Use Case Examples</th>
#       <th>Resources Required</th>
#       <th>Pricing</th>
#       <th>Notes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Document Processing</td>
#       <td>Tesseract</td>
#       <td>OCR, basic text extraction</td>
#       <td>CPU-based, low memory</td>
#       <td>Free &amp; Open-Source</td>
#       <td>A well-established solution for basic OCR tasks.</td>
#     </tr>
#     <tr>
#       <td>Document Processing</td>
#       <td>LayoutLM</td>
#       <td>Form extraction, layout analysis, contextual understanding</td>
#       <td>GPU recommended for training/inference</td>
#       <td>Free &amp; Open-Source</td>
#       <td>Excels at capturing document structure and context.</td>
#     </tr>
#     <tr>
#       <td>Document Processing</td>
#       <td>Donut</td>
#       <td>End-to-end document understanding (no explicit OCR required)</td>
#       <td>GPU recommended for training/inference</td>
#       <td>Free &amp; Open-Source</td>
#       <td>Integrates vision and language to understand documents holistically.</td>
#     </tr>
#     <tr>
#       <td>NLP</td>
#       <td>GPT-3 / GPT-4</td>
#       <td>Text generation, summarization, Q&amp;A, translation</td>
#       <td>High-end GPUs for training; accessed via cloud API</td>
#       <td>Paid API (subscription-based)</td>
#       <td>State-of-the-art performance; ideal for production-level language tasks.</td>
#     </tr>
#     <tr>
#       <td>NLP</td>
#       <td>LLaMA 2</td>
#       <td>Text generation, summarization, Q&amp;A, language understanding</td>
#       <td>High-end GPUs for training/inference</td>
#       <td>Free &amp; Open-Source</td>
#       <td>A competitive open-source alternative offering strong performance.</td>
#     </tr>
#     <tr>
#       <td>NLP</td>
#       <td>BERT / RoBERTa</td>
#       <td>Sentiment analysis, question answering, language understanding</td>
#       <td>High-end GPUs for training; lightweight inference possible on CPU</td>
#       <td>Free &amp; Open-Source</td>
#       <td>Widely adopted; requires fine-tuning for domain-specific tasks.</td>
#     </tr>
#     <tr>
#       <td>NLP</td>
#       <td>GPT-NeoX</td>
#       <td>Text generation, summarization, language modeling</td>
#       <td>High-end GPUs; large memory footprint</td>
#       <td>Free &amp; Open-Source</td>
#       <td>Community-driven alternative to proprietary GPT models.</td>
#     </tr>
#     <tr>
#       <td>NLP</td>
#       <td>T5 / FLAN-T5</td>
#       <td>Text summarization, translation, classification</td>
#       <td>High-end GPUs for training; smaller versions can run on CPU</td>
#       <td>Free &amp; Open-Source</td>
#       <td>A versatile text-to-text transformer adaptable to multiple NLP tasks.</td>
#     </tr>
#     <tr>
#       <td>NLP</td>
#       <td>BLOOM</td>
#       <td>Multilingual text generation, summarization</td>
#       <td>High-end GPUs for training/inference</td>
#       <td>Free &amp; Open-Source</td>
#       <td>Designed for multilingual tasks with competitive performance across languages.</td>
#     </tr>
#     <tr>
#       <td>Computer Vision</td>
#       <td>YOLO (v5/v8)</td>
#       <td>Object detection, image classification, real-time detection</td>
#       <td>Moderate to high GPU usage for training/inference</td>
#       <td>Free &amp; Open-Source; cloud GPUs billed by usage</td>
#       <td>Widely adopted for real-time object detection tasks.</td>
#     </tr>
#     <tr>
#       <td>Computer Vision</td>
#       <td>DETR</td>
#       <td>Object detection, segmentation</td>
#       <td>High-end GPUs required for training/inference</td>
#       <td>Free &amp; Open-Source</td>
#       <td>Transformer-based model developed by Facebook AI for object detection and segmentation.</td>
#     </tr>
#     <tr>
#       <td>Computer Vision</td>
#       <td>Swin Transformer</td>
#       <td>Image classification, detection, segmentation</td>
#       <td>High-end GPUs recommended</td>
#       <td>Free &amp; Open-Source</td>
#       <td>State-of-the-art transformer architecture, excelling in various vision tasks.</td>
#     </tr>
#     <tr>
#       <td>Speech Processing</td>
#       <td>Wav2Vec2</td>
#       <td>Speech-to-text, voice recognition</td>
#       <td>GPU recommended for training/inference; CPU can suffice for smaller models</td>
#       <td>Free &amp; Open-Source; cloud usage costs may apply</td>
#       <td>Robust speech recognition model leveraging self-supervised learning.</td>
#     </tr>
#     <tr>
#       <td>Speech Processing</td>
#       <td>Whisper</td>
#       <td>Speech recognition, transcription, translation</td>
#       <td>High-end GPUs recommended for faster inference; CPU for smaller models</td>
#       <td>Free &amp; Open-Source; cloud usage costs may apply</td>
#       <td>OpenAI’s model offering robust, multilingual transcription and translation performance.</td>
#     </tr>
#   </tbody>
# </table>
